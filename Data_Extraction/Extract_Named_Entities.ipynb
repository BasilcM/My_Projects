# %%
# !pip3 install spacy
# Out:
# Collecting spacy
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/f3/80/c3c0d15cc3ea97c1fd578c39489ef6c360ec0fedfbf15cb29fd89dcf3271/spacy-2.3.1-cp36-cp36m-manylinux1_x86_64.whl (9.9MB)
#     100% |████████████████████████████████| 9.9MB 128kB/s ta 0:00:01
# Collecting wasabi<1.1.0,>=0.4.0 (from spacy)
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/04/e5/aa1892776a8ed6f6d552ba1be0640e6403f07e850d36e79f475f1e605aa9/wasabi-0.7.0.tar.gz
# Collecting thinc==7.4.1 (from spacy)
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/10/ae/ef3ae5e93639c0ef8e3eb32e3c18341e511b3c515fcfc603f4b808087651/thinc-7.4.1-cp36-cp36m-manylinux1_x86_64.whl (2.1MB)
#     100% |████████████████████████████████| 2.1MB 480kB/s ta 0:00:01
# Collecting numpy>=1.15.0 (from spacy)
#   Cache entry deserialization failed, entry ignored
#   Using cached https://files.pythonhosted.org/packages/00/16/476826a84d545424084499763248abbbdc73d065168efed9aa71cdf2a7dc/numpy-1.19.0-cp36-cp36m-manylinux1_x86_64.whl
# Collecting catalogue<1.1.0,>=0.0.7 (from spacy)
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/6c/f9/9a5658e2f56932e41eb264941f9a2cb7f3ce41a80cb36b2af6ab78e2f8af/catalogue-1.0.0-py2.py3-none-any.whl
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/e7/b5/3e1714ebda8fd7c5859f9b216e381adc0a38b962f071568fd00d67e1b1ca/cymem-2.0.3-cp36-cp36m-manylinux1_x86_64.whl
# Collecting setuptools (from spacy)
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/41/fa/60888a1d591db07bc9c17dce2bcfb9f00ac507c0a23ecb827e76feb8f816/setuptools-49.1.0-py3-none-any.whl (789kB)
#     100% |████████████████████████████████| 798kB 729kB/s ta 0:00:01
# Collecting blis<0.5.0,>=0.4.0 (from spacy)
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/41/19/f95c75562d18eb27219df3a3590b911e78d131b68466ad79fdf5847eaac4/blis-0.4.1-cp36-cp36m-manylinux1_x86_64.whl (3.7MB)
#     100% |████████████████████████████████| 3.7MB 331kB/s ta 0:00:011
# Collecting plac<1.2.0,>=0.9.6 (from spacy)
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/86/85/40b8f66c2dd8f4fd9f09d59b22720cffecf1331e788b8a0cab5bafb353d1/plac-1.1.3-py2.py3-none-any.whl
# Collecting tqdm<5.0.0,>=4.38.0 (from spacy)
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/46/62/7663894f67ac5a41a0d8812d78d9d2a9404124051885af9d77dc526fb399/tqdm-4.47.0-py2.py3-none-any.whl (66kB)
#     100% |████████████████████████████████| 71kB 2.1MB/s ta 0:00:011
# Collecting requests<3.0.0,>=2.13.0 (from spacy)
#   Using cached https://files.pythonhosted.org/packages/45/1e/0c169c6a5381e241ba7404532c16a21d86ab872c9bed8bdcd4c423954103/requests-2.24.0-py2.py3-none-any.whl
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/db/6b/e07fad36913879757c90ba03d6fb7f406f7279e11dcefc105ee562de63ea/preshed-3.0.2-cp36-cp36m-manylinux1_x86_64.whl (119kB)
#     100% |████████████████████████████████| 122kB 1.0MB/s ta 0:00:01
# Collecting srsly<1.1.0,>=1.0.2 (from spacy)
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/0e/9a/70bd934dd4d25545c9aa6c8cd4edbac2a33ba9c915439a9209b69f0ec0ad/srsly-1.0.2-cp36-cp36m-manylinux1_x86_64.whl (185kB)
#     100% |████████████████████████████████| 194kB 1.1MB/s ta 0:00:01
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/a6/e6/63f160a4fdf0e875d16b28f972083606d8d54f56cd30cb8929f9a1ee700e/murmurhash-1.0.2-cp36-cp36m-manylinux1_x86_64.whl
# Collecting importlib-metadata>=0.20; python_version < "3.8" (from catalogue<1.1.0,>=0.0.7->spacy)
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/8e/58/cdea07eb51fc2b906db0968a94700866fc46249bdc75cac23f9d13168929/importlib_metadata-1.7.0-py2.py3-none-any.whl
# Collecting chardet<4,>=3.0.2 (from requests<3.0.0,>=2.13.0->spacy)
#   Using cached https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 (from requests<3.0.0,>=2.13.0->spacy)
#   Using cached https://files.pythonhosted.org/packages/e1/e5/df302e8017440f111c11cc41a6b432838672f5a70aa29227bf58149dc72f/urllib3-1.25.9-py2.py3-none-any.whl
# Collecting idna<3,>=2.5 (from requests<3.0.0,>=2.13.0->spacy)
#   Using cached https://files.pythonhosted.org/packages/a2/38/928ddce2273eaa564f6f50de919327bf3a00f091b5baba8dfa9460f3a8a8/idna-2.10-py2.py3-none-any.whl
# Collecting certifi>=2017.4.17 (from requests<3.0.0,>=2.13.0->spacy)
#   Using cached https://files.pythonhosted.org/packages/5e/c4/6c4fe722df5343c33226f0b4e0bb042e4dc13483228b4718baf286f86d87/certifi-2020.6.20-py2.py3-none-any.whl
# Collecting zipp>=0.5 (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy)
#   Cache entry deserialization failed, entry ignored
#   Using cached https://files.pythonhosted.org/packages/b2/34/bfcb43cc0ba81f527bc4f40ef41ba2ff4080e047acb0586b56b3d017ace4/zipp-3.1.0-py3-none-any.whl
# Building wheels for collected packages: wasabi
#   Running setup.py bdist_wheel for wasabi ... done
#   Stored in directory: /home/qmis/.cache/pip/wheels/33/96/74/01741d5dde3d866a4461a05b3fc6aa43bd7ece8729a7264bf7
# Successfully built wasabi
# Installing collected packages: wasabi, cymem, murmurhash, preshed, zipp, importlib-metadata, catalogue, numpy, blis, plac, srsly, tqdm, thinc, setuptools, chardet, urllib3, idna, certifi, requests, spacy
# Successfully installed blis-0.4.1 catalogue-1.0.0 certifi-2020.6.20 chardet-3.0.4 cymem-2.0.3 idna-2.10 importlib-metadata-1.7.0 murmurhash-1.0.2 numpy-1.19.0 plac-1.1.3 preshed-3.0.2 requests-2.24.0 setuptools-49.1.0 spacy-2.3.1 srsly-1.0.2 thinc-7.4.1 tqdm-4.47.0 urllib3-1.25.9 wasabi-0.7.0 zipp-3.1.0

# %%
# !python3 -m spacy download en_core_web_sm
# Out:
# Collecting en_core_web_sm==2.3.1 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz#egg=en_core_web_sm==2.3.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz (12.0MB)
#     100% |████████████████████████████████| 12.1MB 1.9MB/s ta 0:00:01
# Collecting spacy<2.4.0,>=2.3.0 (from en_core_web_sm==2.3.1)
#   Downloading https://files.pythonhosted.org/packages/f3/80/c3c0d15cc3ea97c1fd578c39489ef6c360ec0fedfbf15cb29fd89dcf3271/spacy-2.3.1-cp36-cp36m-manylinux1_x86_64.whl (9.9MB)
#     100% |████████████████████████████████| 9.9MB 2.4MB/s ta 0:00:01    27% |█████████                       | 2.8MB 1.1MB/s eta 0:00:07
# Collecting thinc==7.4.1 (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1)
#   Downloading https://files.pythonhosted.org/packages/10/ae/ef3ae5e93639c0ef8e3eb32e3c18341e511b3c515fcfc603f4b808087651/thinc-7.4.1-cp36-cp36m-manylinux1_x86_64.whl (2.1MB)
#     100% |████████████████████████████████| 2.1MB 1.5MB/s ta 0:00:01
# Collecting srsly<1.1.0,>=1.0.2 (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1)
#   Downloading https://files.pythonhosted.org/packages/0e/9a/70bd934dd4d25545c9aa6c8cd4edbac2a33ba9c915439a9209b69f0ec0ad/srsly-1.0.2-cp36-cp36m-manylinux1_x86_64.whl (185kB)
#     100% |████████████████████████████████| 194kB 2.3MB/s ta 0:00:01
# Collecting plac<1.2.0,>=0.9.6 (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1)
#   Downloading https://files.pythonhosted.org/packages/86/85/40b8f66c2dd8f4fd9f09d59b22720cffecf1331e788b8a0cab5bafb353d1/plac-1.1.3-py2.py3-none-any.whl
# Collecting catalogue<1.1.0,>=0.0.7 (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1)
#   Downloading https://files.pythonhosted.org/packages/6c/f9/9a5658e2f56932e41eb264941f9a2cb7f3ce41a80cb36b2af6ab78e2f8af/catalogue-1.0.0-py2.py3-none-any.whl
# Collecting preshed<3.1.0,>=3.0.2 (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1)
#   Downloading https://files.pythonhosted.org/packages/db/6b/e07fad36913879757c90ba03d6fb7f406f7279e11dcefc105ee562de63ea/preshed-3.0.2-cp36-cp36m-manylinux1_x86_64.whl (119kB)
#     100% |████████████████████████████████| 122kB 472kB/s ta 0:00:01
# Collecting setuptools (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1)
#   Downloading https://files.pythonhosted.org/packages/41/fa/60888a1d591db07bc9c17dce2bcfb9f00ac507c0a23ecb827e76feb8f816/setuptools-49.1.0-py3-none-any.whl (789kB)
#     100% |████████████████████████████████| 798kB 1.2MB/s ta 0:00:01
# Collecting requests<3.0.0,>=2.13.0 (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1)
#   Downloading https://files.pythonhosted.org/packages/45/1e/0c169c6a5381e241ba7404532c16a21d86ab872c9bed8bdcd4c423954103/requests-2.24.0-py2.py3-none-any.whl (61kB)
#     100% |████████████████████████████████| 71kB 7.8MB/s ta 0:00:011
# Collecting tqdm<5.0.0,>=4.38.0 (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1)
#   Downloading https://files.pythonhosted.org/packages/46/62/7663894f67ac5a41a0d8812d78d9d2a9404124051885af9d77dc526fb399/tqdm-4.47.0-py2.py3-none-any.whl (66kB)
#     100% |████████████████████████████████| 71kB 1.3MB/s ta 0:00:01
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1)
#   Downloading https://files.pythonhosted.org/packages/a6/e6/63f160a4fdf0e875d16b28f972083606d8d54f56cd30cb8929f9a1ee700e/murmurhash-1.0.2-cp36-cp36m-manylinux1_x86_64.whl
# Collecting wasabi<1.1.0,>=0.4.0 (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1)
#   Downloading https://files.pythonhosted.org/packages/04/e5/aa1892776a8ed6f6d552ba1be0640e6403f07e850d36e79f475f1e605aa9/wasabi-0.7.0.tar.gz
# Collecting numpy>=1.15.0 (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1)
#   Downloading https://files.pythonhosted.org/packages/00/16/476826a84d545424084499763248abbbdc73d065168efed9aa71cdf2a7dc/numpy-1.19.0-cp36-cp36m-manylinux1_x86_64.whl (13.5MB)
#     100% |████████████████████████████████| 13.5MB 2.6MB/s ta 0:00:011
# Collecting cymem<2.1.0,>=2.0.2 (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1)
#   Downloading https://files.pythonhosted.org/packages/e7/b5/3e1714ebda8fd7c5859f9b216e381adc0a38b962f071568fd00d67e1b1ca/cymem-2.0.3-cp36-cp36m-manylinux1_x86_64.whl
# Collecting blis<0.5.0,>=0.4.0 (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1)
#   Downloading https://files.pythonhosted.org/packages/41/19/f95c75562d18eb27219df3a3590b911e78d131b68466ad79fdf5847eaac4/blis-0.4.1-cp36-cp36m-manylinux1_x86_64.whl (3.7MB)
#     100% |████████████████████████████████| 3.7MB 1.5MB/s ta 0:00:01
# Collecting importlib-metadata>=0.20; python_version < "3.8" (from catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1)
#   Downloading https://files.pythonhosted.org/packages/8e/58/cdea07eb51fc2b906db0968a94700866fc46249bdc75cac23f9d13168929/importlib_metadata-1.7.0-py2.py3-none-any.whl
# Collecting chardet<4,>=3.0.2 (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1)
#   Downloading https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl (133kB)
#     100% |████████████████████████████████| 143kB 2.0MB/s ta 0:00:01
# Collecting idna<3,>=2.5 (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1)
#   Downloading https://files.pythonhosted.org/packages/a2/38/928ddce2273eaa564f6f50de919327bf3a00f091b5baba8dfa9460f3a8a8/idna-2.10-py2.py3-none-any.whl (58kB)
#     100% |████████████████████████████████| 61kB 1.7MB/s ta 0:00:01
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1)
#   Downloading https://files.pythonhosted.org/packages/e1/e5/df302e8017440f111c11cc41a6b432838672f5a70aa29227bf58149dc72f/urllib3-1.25.9-py2.py3-none-any.whl (126kB)
#     100% |████████████████████████████████| 133kB 7.0MB/s ta 0:00:01
# Collecting certifi>=2017.4.17 (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1)
#   Downloading https://files.pythonhosted.org/packages/5e/c4/6c4fe722df5343c33226f0b4e0bb042e4dc13483228b4718baf286f86d87/certifi-2020.6.20-py2.py3-none-any.whl (156kB)
#     100% |████████████████████████████████| 163kB 2.0MB/s ta 0:00:01
# Collecting zipp>=0.5 (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1)
#   Downloading https://files.pythonhosted.org/packages/b2/34/bfcb43cc0ba81f527bc4f40ef41ba2ff4080e047acb0586b56b3d017ace4/zipp-3.1.0-py3-none-any.whl
# Installing collected packages: plac, zipp, importlib-metadata, catalogue, cymem, murmurhash, preshed, wasabi, tqdm, srsly, numpy, blis, thinc, setuptools, chardet, idna, urllib3, certifi, requests, spacy, en-core-web-sm
#   Running setup.py install for wasabi ... done
#   Running setup.py install for en-core-web-sm ... done
# Successfully installed blis-0.4.1 catalogue-1.0.0 certifi-2020.6.20 chardet-3.0.4 cymem-2.0.3 en-core-web-sm-2.3.1 idna-2.10 importlib-metadata-1.7.0 murmurhash-1.0.2 numpy-1.19.0 plac-1.1.3 preshed-3.0.2 requests-2.24.0 setuptools-49.1.0 spacy-2.3.1 srsly-1.0.2 thinc-7.4.1 tqdm-4.47.0 urllib3-1.25.9 wasabi-0.7.0 zipp-3.1.0
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# Segmentation fault (core dumped)

# %%
from flask import Flask,render_template,url_for,request
import re
import pandas as pd
import spacy
from spacy import displacy
import en_core_web_sm
nlp = spacy.load('en_core_web_sm')

# %%
app = Flask(__name__)

@app.route('/')
def index():
    return render_template("index.html")

# %%
@app.route('/process',methods=["POST"])
def process():
    if request.method == 'POST':
        choice = request.form['taskoption']
        rawtext = request.form['rawtext']
        doc = nlp(rawtext)
        d = []
        for ent in doc.ents:
            d.append((ent.label_, ent.text))
            df = pd.DataFrame(d, columns=('named entity', 'output'))
            ORG_named_entity = df.loc[df['named entity'] == 'ORG']['output']
            PERSON_named_entity = df.loc[df['named entity'] == 'PERSON']['output']
            GPE_named_entity = df.loc[df['named entity'] == 'GPE']['output']
            MONEY_named_entity = df.loc[df['named entity'] == 'MONEY']['output']
            FAC_named_entity = df.loc[df['named entity'] == 'FAC']['output']
            PRODUCT_named_entity = df.loc[df['named entity'] == 'PRODUCT']['output']
            EVENT_named_entity = df.loc[df['named entity'] == 'EVENT']['output']
        if choice == 'organization':
            results = ORG_named_entity
            num_of_results = len(results)
        elif choice == 'person':
            results = PERSON_named_entity
            num_of_results = len(results)
        elif choice == 'geopolitical':
            results = GPE_named_entity
            num_of_results = len(results)
        elif choice == 'money':
            results = MONEY_named_entity
            num_of_results = len(results)
        elif choice == 'fact':
            results = FAC_named_entity
            num_of_results = len(results)
        elif choice == 'topic':
            results = PRODUCT_named_entity
            num_of_results = len(results)
        elif choice == 'event':
            results = EVENT_named_entity
            num_of_results = len(results)

    return render_template("index.html",results=results,num_of_results = num_of_results)

# %%
if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# [2020-07-10 22:19:10,523] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-2-3befffdac73c>", line 5, in index
#     return render_template("index.html")
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/templating.py", line 138, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/home/qmis/.local/lib/python3.6/site-packages/jinja2/environment.py", line 930, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/home/qmis/.local/lib/python3.6/site-packages/jinja2/environment.py", line 883, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "/home/qmis/.local/lib/python3.6/site-packages/jinja2/environment.py", line 857, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "/home/qmis/.local/lib/python3.6/site-packages/jinja2/loaders.py", line 115, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/templating.py", line 60, in get_source
#     return self._get_source_fast(environment, template)
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/templating.py", line 89, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: index.html
# 127.0.0.1 - - [10/Jul/2020 22:19:10] "GET / HTTP/1.1" 500 -
# 127.0.0.1 - - [10/Jul/2020 22:19:11] "GET /favicon.ico HTTP/1.1" 404 -
# [2020-07-10 22:19:19,887] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-2-3befffdac73c>", line 5, in index
#     return render_template("index.html")
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/templating.py", line 138, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/home/qmis/.local/lib/python3.6/site-packages/jinja2/environment.py", line 930, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/home/qmis/.local/lib/python3.6/site-packages/jinja2/environment.py", line 883, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "/home/qmis/.local/lib/python3.6/site-packages/jinja2/environment.py", line 857, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "/home/qmis/.local/lib/python3.6/site-packages/jinja2/loaders.py", line 115, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/templating.py", line 60, in get_source
#     return self._get_source_fast(environment, template)
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/templating.py", line 89, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: index.html
# 127.0.0.1 - - [10/Jul/2020 22:19:19] "GET / HTTP/1.1" 500 -
# 127.0.0.1 - - [10/Jul/2020 22:20:06] "GET /sample HTTP/1.1" 404 -
# 127.0.0.1 - - [10/Jul/2020 22:20:07] "GET /favicon.ico HTTP/1.1" 404 -
# [2020-07-10 22:20:09,509] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-2-3befffdac73c>", line 5, in index
#     return render_template("index.html")
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/templating.py", line 138, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/home/qmis/.local/lib/python3.6/site-packages/jinja2/environment.py", line 930, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/home/qmis/.local/lib/python3.6/site-packages/jinja2/environment.py", line 883, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "/home/qmis/.local/lib/python3.6/site-packages/jinja2/environment.py", line 857, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "/home/qmis/.local/lib/python3.6/site-packages/jinja2/loaders.py", line 115, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/templating.py", line 60, in get_source
#     return self._get_source_fast(environment, template)
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/templating.py", line 89, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: index.html
# 127.0.0.1 - - [10/Jul/2020 22:20:09] "GET / HTTP/1.1" 500 -
# 127.0.0.1 - - [10/Jul/2020 22:22:21] "GET /predict HTTP/1.1" 404 -
# 127.0.0.1 - - [10/Jul/2020 22:24:32] "GET /view/index.html HTTP/1.1" 404 -
# 127.0.0.1 - - [10/Jul/2020 22:24:37] "GET /index.html HTTP/1.1" 404 -
# 127.0.0.1 - - [10/Jul/2020 22:25:00] "GET /view/index.html HTTP/1.1" 404 -
# 127.0.0.1 - - [10/Jul/2020 22:25:07] "GET /view/index.html HTTP/1.1" 404 -
# [2020-07-10 22:26:46,837] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-2-3befffdac73c>", line 5, in index
#     return render_template("index.html")
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/templating.py", line 138, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/home/qmis/.local/lib/python3.6/site-packages/jinja2/environment.py", line 930, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/home/qmis/.local/lib/python3.6/site-packages/jinja2/environment.py", line 883, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "/home/qmis/.local/lib/python3.6/site-packages/jinja2/environment.py", line 857, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "/home/qmis/.local/lib/python3.6/site-packages/jinja2/loaders.py", line 115, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/templating.py", line 60, in get_source
#     return self._get_source_fast(environment, template)
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/templating.py", line 89, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: index.html
# 127.0.0.1 - - [10/Jul/2020 22:26:46] "GET / HTTP/1.1" 500 -
# 127.0.0.1 - - [10/Jul/2020 22:28:56] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jul/2020 22:28:56] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [10/Jul/2020 22:28:56] "GET /main.js HTTP/1.1" 404 -
# [2020-07-10 22:29:09,323] ERROR in app: Exception on /process [POST]
# Traceback (most recent call last):
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/qmis/.local/lib/python3.6/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-3-9f912eb1aee3>", line 40, in process
#     return render_template("index.html",results=results,num_of_results = num_of_results)
# UnboundLocalError: local variable 'results' referenced before assignment
# 127.0.0.1 - - [10/Jul/2020 22:29:09] "POST /process HTTP/1.1" 500 -
# 127.0.0.1 - - [10/Jul/2020 22:29:32] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jul/2020 22:29:32] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [10/Jul/2020 22:29:32] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [10/Jul/2020 22:29:41] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jul/2020 22:29:41] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [10/Jul/2020 22:29:41] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [10/Jul/2020 22:30:19] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jul/2020 22:30:19] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [10/Jul/2020 22:30:19] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [10/Jul/2020 22:30:35] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jul/2020 22:30:35] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [10/Jul/2020 22:30:35] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [10/Jul/2020 22:30:40] "GET /process HTTP/1.1" 405 -
# 127.0.0.1 - - [10/Jul/2020 22:31:41] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jul/2020 22:31:41] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [10/Jul/2020 22:31:41] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [10/Jul/2020 22:31:50] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jul/2020 22:31:50] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [10/Jul/2020 22:31:50] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [10/Jul/2020 22:32:10] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jul/2020 22:32:10] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [10/Jul/2020 22:32:10] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [10/Jul/2020 22:32:17] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jul/2020 22:32:17] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [10/Jul/2020 22:32:18] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [10/Jul/2020 22:32:35] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jul/2020 22:32:35] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [10/Jul/2020 22:32:35] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [11/Jul/2020 01:03:59] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jul/2020 01:03:59] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [11/Jul/2020 01:03:59] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [11/Jul/2020 01:04:03] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jul/2020 01:04:03] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [11/Jul/2020 01:04:03] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [11/Jul/2020 01:04:05] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jul/2020 01:04:05] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [11/Jul/2020 01:04:05] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [11/Jul/2020 01:04:08] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jul/2020 01:04:08] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [11/Jul/2020 01:04:08] "GET /main.js HTTP/1.1" 404 -
# 127.0.0.1 - - [11/Jul/2020 01:04:52] "POST /process HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jul/2020 01:04:52] "GET /main.css HTTP/1.1" 404 -
# 127.0.0.1 - - [11/Jul/2020 01:04:52] "GET /main.js HTTP/1.1" 404 -
